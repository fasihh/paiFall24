# %%
import pandas as pd

df = pd.read_csv('heart.csv')

# %%
print(df['cp'].unique())
df_cp2 = df[df['cp'] == 2]
df_cp2
# Out:
# [0 1 2 3]
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 16     51    0   2       140   308    0        0      142      0      1.5
# 19     58    1   2       140   211    1        0      165      0      0.0
# 20     60    1   2       140   185    0        0      155      0      3.0
# 23     63    0   2       135   252    0        0      172      0      0.0
# 24     42    0   2       120   209    0        1      173      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 973    51    1   2       125   245    1        0      166      0      2.4
# 985    62    1   2       130   231    0        1      146      0      1.8
# 1004   51    0   2       140   308    0        0      142      0      1.5
# 1006   58    1   2       140   211    1        0      165      0      0.0
# 1014   44    0   2       108   141    0        1      175      0      0.6
#
#       slope  ca  thal  target
# 16        2   1     2       1
# ...

# %%
df.groupby('cp').mean()
# Out:
#           age       sex    trestbps        chol       fbs   restecg  \
# cp
# 0   55.784708  0.732394  132.213280  249.993964  0.132797  0.480885
# 1   51.245509  0.658683  128.119760  244.700599  0.095808  0.616766
# 2   53.517606  0.616197  130.077465  242.197183  0.193662  0.598592
# 3   56.012987  0.831169  140.961039  237.064935  0.207792  0.402597
#
#        thalach     exang   oldpeak     slope        ca      thal    target
# cp
# 0   140.052314  0.569416  1.438833  1.243461  0.981891  2.454728  0.245473
# 1   162.179641  0.071856  0.323952  1.658683  0.425150  2.155689  0.802395
# 2   155.116197  0.130282  0.784507  1.507042  0.619718  2.211268  0.771127
# 3   157.129870  0.168831  1.380519  1.259740  0.493506  2.259740  0.662338

# %%
# 4 categories
# single group, single column
# single group, multi columns
# multi group, single clolumn
# multi group, multi columns

# %%
df = df.rename(columns={'sex': 'gender'})
df['gender'] = df['gender'].replace({1: 'Male', 0: 'Female'})

# %%
# single g
df1 = df.groupby('gender')
# single c
df1['chol'].agg(['max', 'median', 'mean'])
# Out:
#         max  median        mean
# gender
# Female  564   254.0  261.455128
# Male    353   234.0  239.237027

# %%
# multi c
df1[['restecg', 'oldpeak', 'chol']].agg(['max', 'median', 'mean'])
# Out:
#        restecg                  oldpeak                  chol         \
#            max median      mean     max median      mean  max median
# gender
# Female       2    1.0  0.573718     6.2    0.6  0.921154  564  254.0
# Male         2    1.0  0.510519     5.6    0.8  1.137307  353  234.0
#
#
#               mean
# gender
# Female  261.455128
# Male    239.237027
